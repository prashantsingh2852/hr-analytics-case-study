# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('employees.csv')

dataset.head()
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %%
dataset.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
list(dataset['dept'].unique())
# Out:
# ['sales',
#  'accounting',
#  'hr',
#  'technical',
#  'support',
#  'IT',
#  'product_mng',
#  'marketing',
#  'management',
#  'RandD']

# %%
dataset.shape   ## To check the overall row & column count
# Out:
# (14999, 10)

# %%
## Data preprocessing

# %%
dataset.isnull().sum()   ## Null value check
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
dataset.duplicated().sum()   ## duplicate check
# Out:
# 3008

# %%
dataset = dataset.drop_duplicates()   ## To delete duplicate rows

# %%
dataset.shape
# Out:
# (11991, 10)

# %%
import seaborn as sns

# %%
sns.heatmap(dataset.corr(),annot = True,cmap = 'Greens')
# Out:
# /var/folders/6l/_1w0bhn90l76r8fg08zzqpkw0000gn/T/ipykernel_12997/1698543135.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dataset.corr(),annot = True,cmap = 'Greens')
# <Axes: >

# %%
## enumerate

# %%
dataset.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
a = ['dept','numberOfProjects','timeSpent.company','workAccident','promotionInLast5years','salary']

a
# Out:
# ['dept',
#  'numberOfProjects',
#  'timeSpent.company',
#  'workAccident',
#  'promotionInLast5years',
#  'salary']

# %%
for i,j in enumerate(a):
    print(i,j)
# Out:
# 0 dept
# 1 numberOfProjects
# 2 timeSpent.company
# 3 workAccident
# 4 promotionInLast5years
# 5 salary

# %%
fig = plt.subplots(3,2,figsize = (30,25))

for i,j in enumerate(a):
    plt.subplot(3,2, i+1)
    sns.countplot(x = j, data = dataset, hue = 'left')
plt.show()

# %%
'''
Conclusions
1. The most no. of people who are churning out belongs to sales department, but the highest attrition rate belongs to technical and support departments.
2. When the number of projects is minimum, the employee might feel that he is being underutilized When the number of projects is maximum, the employee might feel that he is being overburdened. 3-4 number of projects are the most suitable ones.
3. The time period of 3-5 years is the most crucial period for the company.
4. Work accident does not play a major role in the emplyees' decision-making.
5. Promotion plays a very significant role in the employees' decision.
6. Most of the employees who are leaving are getting low/medium salary.
'''
